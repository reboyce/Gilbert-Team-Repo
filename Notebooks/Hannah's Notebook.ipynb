# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('Files/tn.movie_budgets.csv.gz')
df
#import csv as a read me file
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df.isnull().sum()
#checking to see if there are any null values in the data set for data cleaning
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
df['production_budget'] = df['production_budget'].str.replace('$','')

df['domestic_gross'] = df['domestic_gross'].str.replace('$','')

df['worldwide_gross'] = df['worldwide_gross'].str.replace('$','')
#getting rid of the dollar signs for numbers to turn them into floats to be able to compare numbers

# %%
df['production_budget'] = df['production_budget'].str.replace(',','')

df['domestic_gross'] = df['domestic_gross'].str.replace(',','')

df['worldwide_gross'] = df['worldwide_gross'].str.replace(',','')
#getting rid of the commas for numbers to turn them into floats to be able to compare numbers

# %%
df.worldwide_gross = df.worldwide_gross.astype(float)
df.domestic_gross = df.domestic_gross.astype(float)
df.production_budget = df.production_budget.astype(float)
#turning all of the number based columns into floats after taking out the commas and dollar signs

# %%
df.info()
#checking to make sure that the columns were converted from objects to integers for further analysis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 271.2+ KB

# %%
df.loc[df['worldwide_gross'] > df['production_budget'], 'Profitability'] = True
df.loc[df['worldwide_gross'] < df['production_budget'], 'Profitability'] = False
df.loc[df['worldwide_gross'] == df['production_budget'], 'Profitability'] = 'Broke Even'
#Creating a new column called profitability to see which movies made more than they spent by using inequality symbols
#Using true and false to easily see which movies were profitable

# %%
df['Profit ($)'] = df['worldwide_gross'] - df['production_budget']
#Creating a new column called profit ($) by subtracting the production_budget away from the worldwide gross to find net
#this column factualizes the profitability column

# %%
df = df.sort_values(['Profit ($)'], ascending=False)
#sorting the profit column so that the most profitable are at the top to analyse if that effects our business
#reccomendations

# %%
df['Profit (millions)'] = '$' + (df['Profit ($)'].astype(float)/1000000).astype(str) + 'MM'
#creating a column that is the Profit ($) colum, but in millions with dollar signs so its more readable
# Out:
#      id  release_date                                 movie  \
# 0     1  Dec 18, 2009                                Avatar
# 42   43  Dec 19, 1997                               Titanic
# 6     7  Apr 27, 2018                Avengers: Infinity War
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 33   34  Jun 12, 2015                        Jurassic World
# ..   ..           ...                                   ...
# 352  53  Apr 27, 2001                        Town & Country
# 341  42  Jun 14, 2019           Men in Black: International
# 193  94  Mar 11, 2011                       Mars Needs Moms
# 194  95  Dec 31, 2020                              Moonfall
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross Profitability  \
# 0          425000000.0     760507625.0     2.776345e+09          True
# 42         200000000.0     659363944.0     2.208208e+09          True
# ...
